# %%
import pandas as pd
import numpy as np
bf=pd.read_csv('cleaned_student_performance.csv')
print(bf)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           90.0           88.0              NaN
# 1  female   69.000000           95.0           93.0             74.0
# 2  female   90.000000           57.0            NaN             78.0
# 3    male   47.000000           78.0           75.0             81.0
# 4    male   52.285714            NaN           78.0             70.0
# 5  female   71.000000           44.0           52.0             12.0
# 6    male   12.000000           65.0           67.0             49.0
# 7    male   52.285714           77.0           89.0             55.0
# 8    male    5.000000           74.0           78.0              NaN
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
bf.isnull()
# Out:
#     Firstname  Lastname  Gender   SPOS  DSBDA     WT     DA
# 0       False     False   False  False  False  False  False
# 1       False     False   False  False  False  False  False
# 2       False     False   False   True  False  False  False
# 3       False     False   False  False  False  False  False
# 4       False     False   False   True  False  False  False
# 5       False     False   False  False   True  False  False
# 6       False     False   False  False  False  False  False
# 7       False     False   False  False  False  False  False
# 8       False     False   False  False  False  False  False
# 9       False     False   False  False   True  False  False
# 10      False     False   False  False  False   True  False
# 11      False     False   False  False   True  False  False

# %%
s=pd.isnull(bf['reading score'])
bf[s]
# Out:
#   gender  math score  reading score  writing score  Placement Score  \
# 4   male   52.285714            NaN           78.0             70.0
#
#    placement offer count Region
# 4                      3   Pune

# %%
s=pd.isnull(bf['Region'])
bf[s]
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 1  female        69.0           95.0           93.0             74.0
# 3    male        47.0           78.0           75.0             81.0
# 5  female        71.0           44.0           52.0             12.0
# 8    male         5.0           74.0           78.0              NaN
#
#    placement offer count Region
# 1                      2    NaN
# 3                      1    NaN
# 5                      4    NaN
# 8                      0    NaN

# %%
bf.notnull()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0    True        True           True           True            False
# 1    True        True           True           True             True
# 2    True        True           True          False             True
# 3    True        True           True           True             True
# 4    True        True          False           True             True
# 5    True        True           True           True             True
# 6    True        True           True           True             True
# 7    True        True           True           True             True
# 8    True        True           True           True            False
#
#    placement offer count  Region
# 0                   True    True
# 1                   True   False
# 2                   True    True
# 3                   True   False
# 4                   True    True
# 5                   True   False
# 6                   True    True
# ...

# %%
s=pd.notnull(bf['math score'])
bf[s]
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           90.0           88.0              NaN
# 1  female   69.000000           95.0           93.0             74.0
# 2  female   90.000000           57.0            NaN             78.0
# 3    male   47.000000           78.0           75.0             81.0
# 4    male   52.285714            NaN           78.0             70.0
# 5  female   71.000000           44.0           52.0             12.0
# 6    male   12.000000           65.0           67.0             49.0
# 7    male   52.285714           77.0           89.0             55.0
# 8    male    5.000000           74.0           78.0              NaN
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
bf['gender']=le.fit_transform(bf['gender'])
newbf=bf
bf
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0       0   72.000000           90.0           88.0              NaN
# 1       0   69.000000           95.0           93.0             74.0
# 2       0   90.000000           57.0            NaN             78.0
# 3       1   47.000000           78.0           75.0             81.0
# 4       1   52.285714            NaN           78.0             70.0
# 5       0   71.000000           44.0           52.0             12.0
# 6       1   12.000000           65.0           67.0             49.0
# 7       1   52.285714           77.0           89.0             55.0
# 8       1    5.000000           74.0           78.0              NaN
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
nd=bf
nd.fillna(0)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0       0   72.000000           90.0           88.0              0.0
# 1       0   69.000000           95.0           93.0             74.0
# 2       0   90.000000           57.0            0.0             78.0
# 3       1   47.000000           78.0           75.0             81.0
# 4       1   52.285714            0.0           78.0             70.0
# 5       0   71.000000           44.0           52.0             12.0
# 6       1   12.000000           65.0           67.0             49.0
# 7       1   52.285714           77.0           89.0             55.0
# 8       1    5.000000           74.0           78.0              0.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2       0
# 2                      2  Nashik
# 3                      1       0
# 4                      3    Pune
# 5                      4       0
# 6                      2  Nashik
# ...

# %%
nbf=bf
nbf.fillna(1)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0       0   72.000000           90.0           88.0              1.0
# 1       0   69.000000           95.0           93.0             74.0
# 2       0   90.000000           57.0            1.0             78.0
# 3       1   47.000000           78.0           75.0             81.0
# 4       1   52.285714            1.0           78.0             70.0
# 5       0   71.000000           44.0           52.0             12.0
# 6       1   12.000000           65.0           67.0             49.0
# 7       1   52.285714           77.0           89.0             55.0
# 8       1    5.000000           74.0           78.0              1.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2       1
# 2                      2  Nashik
# 3                      1       1
# 4                      3    Pune
# 5                      4       1
# 6                      2  Nashik
# ...

# %%
mv=bf['math score'].mean()
bf['math score'].fillna(value=mv,inplace=True)
bf
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3300\266064817.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   bf['math score'].fillna(value=mv,inplace=True)
#    gender  math score  reading score  writing score  Placement Score  \
# 0       0   72.000000           90.0           88.0              NaN
# 1       0   69.000000           95.0           93.0             74.0
# 2       0   90.000000           57.0            NaN             78.0
# 3       1   47.000000           78.0           75.0             81.0
# ...

# %%
nbf.replace(to_replace=np.nan,value=-99)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0       0   72.000000           90.0           88.0            -99.0
# 1       0   69.000000           95.0           93.0             74.0
# 2       0   90.000000           57.0          -99.0             78.0
# 3       1   47.000000           78.0           75.0             81.0
# 4       1   52.285714          -99.0           78.0             70.0
# 5       0   71.000000           44.0           52.0             12.0
# 6       1   12.000000           65.0           67.0             49.0
# 7       1   52.285714           77.0           89.0             55.0
# 8       1    5.000000           74.0           78.0            -99.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     -99
# 2                      2  Nashik
# 3                      1     -99
# 4                      3    Pune
# 5                      4     -99
# 6                      2  Nashik
# ...

# %%
nbf.dropna()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 6       1   12.000000           65.0           67.0             49.0
# 7       1   52.285714           77.0           89.0             55.0
#
#    placement offer count  Region
# 6                      2  Nashik
# 7                      1    Pune

# %%
nbf.dropna(how='all')
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0       0   72.000000           90.0           88.0              NaN
# 1       0   69.000000           95.0           93.0             74.0
# 2       0   90.000000           57.0            NaN             78.0
# 3       1   47.000000           78.0           75.0             81.0
# 4       1   52.285714            NaN           78.0             70.0
# 5       0   71.000000           44.0           52.0             12.0
# 6       1   12.000000           65.0           67.0             49.0
# 7       1   52.285714           77.0           89.0             55.0
# 8       1    5.000000           74.0           78.0              NaN
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
nbf.dropna(axis=1)
# Out:
#    gender  math score  placement offer count
# 0       0   72.000000                      1
# 1       0   69.000000                      2
# 2       0   90.000000                      2
# 3       1   47.000000                      1
# 4       1   52.285714                      3
# 5       0   71.000000                      4
# 6       1   12.000000                      2
# 7       1   52.285714                      1
# 8       1    5.000000                      0

# %%
nbf.dropna(axis=0)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 6       1   12.000000           65.0           67.0             49.0
# 7       1   52.285714           77.0           89.0             55.0
#
#    placement offer count  Region
# 6                      2  Nashik
# 7                      1    Pune

# %%
nbf.dropna(axis=0,how='any')
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 6       1   12.000000           65.0           67.0             49.0
# 7       1   52.285714           77.0           89.0             55.0
#
#    placement offer count  Region
# 6                      2  Nashik
# 7                      1    Pune
